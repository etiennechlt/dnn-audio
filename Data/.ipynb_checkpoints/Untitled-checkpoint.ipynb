# %%
mat_hss_deb = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730hss.mat')
mat_hss_fin = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-04-28-0759hss.mat')
sig_hss = []
features = []

for subdir, dirs, files in os.walk("/home/ptit/Documents/projet_eolien/Data"):
    for file in files:
        if ('hss' in file):
            subpath = os.path.join(subdir, file)
            mat = scipy.io.loadmat(subpath)
            features.append(file[0:17])
            signal = mat['hss'][0][0][4]
            sig_hss.append(signal[0])

            
#sorted(mat_contents.keys())

print(sig_hss)
corr_hss = np.corrcoef(sig_hss)
print(corr_hss)
plt.imshow(corr_hss, vmin=0, vmax=1, cmap='coolwarm')
#plt.xlabel(features)
plt.colorbar()
# Out:
# [array([2012.63438759, 2013.29786863, 2013.60932386, ..., 2014.61952729,
#        2015.04819631, 2015.49395815]), array([2012.78022123, 2013.11843233, 2013.57041344, ..., 2014.75931508,
#        2014.74071528, 2014.83495884]), array([2014.14236804, 2013.51923289, 2012.65772517, ..., 2015.22023796,
#        2015.11884577, 2014.16035583]), array([2014.81604948, 2014.97884216, 2014.95493672, ..., 1984.57359106,
#        1983.11259801, 1981.55449989]), array([2013.5433756 , 2013.86038341, 2014.32190892, ..., 2015.2479425 ,
#        2014.72074899, 2013.14352455]), array([2013.62284811, 2014.03000857, 2013.85923926, ..., 2015.68114204,
#        2015.5053418 , 2014.42862176])]
# [[ 1.         -0.18834287  0.11992463 -0.03133977  0.19337775  0.07973774]
#  [-0.18834287  1.         -0.12396525  0.06387592 -0.16492818  0.0710892 ]
#  [ 0.11992463 -0.12396525  1.         -0.0924316   0.01635545  0.21489323]
#  [-0.03133977  0.06387592 -0.0924316   1.         -0.02169456 -0.0607541 ]
# ...

# %%
for subdir, dirs, files in os.walk("/home/ptit/Documents/projet_eolien/Data"):
    for file in files:
        if ('hss' in file):
            subpath = os.path.join(subdir, file)
            mat = scipy.io.loadmat(subpath)
            features.append(file[0:17])
            signal = mat['hss'][0][0][4]
            sig_hss.append(signal)

print(len(sig_hss))
fft = scipy.fft.fft(sig_hss[9][:-200])
plt.figure()
plt.plot(np.abs(fft[1:2000]))
plt.show()

# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
mat_lss_deb = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730lss.mat')
mat_lss_fin = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-04-28-0759lss.mat')

print(sorted(mat_lss_deb.keys()))
print(mat_lss_deb)

signal_lss_deb = mat_lss_deb['lss'][0][0][4]
signal_lss_fin = mat_lss_fin['lss'][0][0][4]
plt.figure()
plt.plot(signal_lss_deb[0,200:-200])
plt.title('lss début')
plt.show()
plt.figure()
plt.plot(signal_lss_fin[0,200:-200])
plt.title('lss fin')
plt.show()
# Out:
# ['__globals__', '__header__', '__version__', 'lss']
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Dec 04 16:38:48 2015', '__version__': '1.0', '__globals__': [], 'lss': array([[(array(['speed LSS'], dtype='<U9'), array(['rpm'], dtype='<U3'), array([[735684.72924334]]), array([[320]], dtype=uint16), array([[20.09157434, 20.02661096, 19.89797498, ..., 20.09648724,
#         19.91436377, 19.83585359]]))]],
#       dtype=[('sensorName', 'O'), ('unit', 'O'), ('timeStamp', 'O'), ('fs', 'O'), ('rawData', 'O')])}

# %%
mat_i1 = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730i1.mat')

signal_i1 = mat_i1['i1'][0][0][4]
plt.figure()
plt.plot(signal_i1[0:100])
plt.show()

# %%
mat_i2 = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730i2.mat')

signal_i2 = mat_i2['i2'][0][0][4]
plt.figure()
plt.plot(signal_i2[0:100])
plt.show()
# Out:
# [[11.90848827]
#  [ 4.41380835]
#  [ 2.62485743]
#  ...
#  [-1.10631347]
#  [ 0.6566453 ]
#  [-3.29295826]]

# %%
mat_vib1 = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730vib1.mat')

signal_vib1 = mat_vib1['vib1'][0][0][4]
#plt.figure()
#plt.plot(signal_vib1[0:100])
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-9-c8f9d9e2676c> in <module>
#       4 plt.figure()
# ----> 5 plt.plot(signal_vib1[0:100])
#       6 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#
# ...

# %%
mat_hss = scipy.io.loadmat('/home/ptit/Documents/projet_eolien/Data/2014-03-26-1730hss.mat')

signal_hss = mat_hss['hss'][0][0][4]
plt.figure()
plt.plot(signal_hss[0,:])
plt.show()
